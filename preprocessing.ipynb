# %% [markdown]
# ##Audience_category Preprocessing

# %%
import pandas as pd

# %%
df = pd.read_csv('audience_profile.csv', sep='!@#')
df=df.drop(['marry','install_pack','asset_index','predicted_house_price'],axis=1)
df_sample=df.sample(frac=0.23, replace=False, random_state=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
train_df =pd.read_csv('train.csv')
train_df=train_df[['device_ifa','click']]
cate_train_df=pd.merge(df,train_df, how='left')
cate_train_df=cate_train_df.dropna(axis=0)
cate_train_df=cate_train_df.drop(['click'],axis=1)
cate_train_df=cate_train_df.drop_duplicates()

# %%
df=pd.concat([df_sample,cate_train_df],axis=0)
df=df.drop_duplicates()
cate = cate_train_df.loc[:,'cate_code']
else_df=df[['device_ifa','age','gender','marry']]

# %% [markdown]
# ###Cate 분해하기

# %%
import numpy as np
a = np.zeros([len(cate),243], dtype= np.object_ )

# %%
for i in range(len(cate)):
  k = str(cate1[i]).split(',') 
  a[i][0:len(k)] = k

for i in range(len(a)):
  j=0
  while a[i][j] != 0:
    a[i][j] = a[i][j][:-2]
    j += 1

colnames1 = set(a[:500000].flatten().tolist())
colnames1 = list(colnames1)
colnames1.remove(0)

# %%
for i in range(len(cate)):
  k = str(cate[i]).split(',') 
  a[i][0:len(k)] = k

# %%
b = np.zeros([len(cate),242], dtype= np.object_ )

for i in range(len(a)):
  for j in range(242):
    if a[i][j]==0:
      break
    id = a[i][j].split(':')
    if id[0]!='nan':
      b[i][colnames1.index(id[0])] = id[1]
      
cate_df = pd.DataFrame(b)

# %% [markdown]
# ###Cate_autoencoder

# %%
#####cate_answer data
cate_ans=cate_df.replace(2, 1)
cate_ans=cate_df.replace(3, 1)
cate_ans=cate_df.replace(4, 1)
cate_ans=cate_df.replace(5, 1)

# %%
#####cate_like data
cate_like=cate_df.replace(1, 0)
cate_like=cate_df.replace(2, 0)
cate_like=cate_df.replace(3, 0)
cate_like=cate_df.replace(4, 1)
cate_like=cate_df.replace(5, 1)

# %%
import keras
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.layers import Input, Dense
from keras.models import Model

from sklearn.preprocessing import OneHotEncoder

# %%
ncol = cate_ans.shape[1] 

input_dim = Input(shape = (ncol, ))
# DEFINE THE DIMENSION OF ENCODER ASSUMED 5
encoding_dim =5
# DEFINE THE ENCODER LAYERS
encoded1 = Dense(64, activation = 'relu')(input_dim)
encoded3 = Dense(32, activation = 'relu')(encoded1)
encoded4 = Dense(encoding_dim, activation = 'relu')(encoded3)
# DEFINE THE DECODER LAYERS
decoded1=Dense(32, activation = 'relu')(encoded4)
decoded3 = Dense(64, activation = 'relu')(decoded1)
decoded4 = Dense(ncol, activation = 'sigmoid')(decoded3)
# COMBINE ENCODER AND DECODER INTO AN AUTOENCODER MODEL
autoencoder = Model(input = input_dim, output = decoded4)
# CONFIGURE AND TRAIN THE AUTOENCODER
autoencoder.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['accuracy'])
autoencoder.fit(cate_ans,cate_ans, nb_epoch = 20, batch_size = 128, shuffle = True)
# THE ENCODER TO EXTRACT THE REDUCED DIMENSION FROM THE ABOVE AUTOENCODER
encoder = Model(input = input_dim, output = encoded4)
encoded_input = Input(shape = (encoding_dim, ))
encoded_out = encoder.predict(cate_ans)

encoded_out_ans=pd.DataFrame(encoded_out,columns=['cate_answer_1','cate_answer_2','cate_answer_3','cate_answer_4','cate_answer_5'])

# %%
input_dim = Input(shape = (ncol, ))
# DEFINE THE DIMENSION OF ENCODER ASSUMED 5
encoding_dim =5
# DEFINE THE ENCODER LAYERS
encoded1 = Dense(128, activation = 'relu')(input_dim)
encoded2 = Dense(64, activation = 'relu')(encoded1)
encoded3 = Dense(16, activation = 'relu')(encoded2)
encoded4 = Dense(encoding_dim, activation = 'relu')(encoded3)
# DEFINE THE DECODER LAYERS
decoded1=Dense(16, activation = 'relu')(encoded4)
decoded2=Dense(64, activation = 'relu')(decoded1)
decoded3 = Dense(128, activation = 'relu')(decoded2)
decoded4 = Dense(ncol, activation = 'sigmoid')(decoded3)
# COMBINE ENCODER AND DECODER INTO AN AUTOENCODER MODEL
autoencoder = Model(input = input_dim, output = decoded4)
# CONFIGURE AND TRAIN THE AUTOENCODER
autoencoder.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['accuracy'])
autoencoder.fit(cate_like,cate_like, nb_epoch = 20, batch_size = 128, shuffle = True)
# THE ENCODER TO EXTRACT THE REDUCED DIMENSION FROM THE ABOVE AUTOENCODER
encoder = Model(input = input_dim, output = encoded4)
encoded_input = Input(shape = (encoding_dim, ))
encoded_out = encoder.predict(cate_like)

encoded_out_like=pd.DataFrame(encoded_out,columns=['cate_like_1','cate_like_2','cate_like_3','cate_like_4','cate_like_5'])

# %%
final_aud=pd.concat([else_df,encoded_out_ans],axis=1)
final_aud=pd.concat([final_aud,encoded_out_like],axis=1)
final_aud.to_csv('audience_preprocess_2.csv',index=False)

# %% [markdown]
# ##Train_preprocessing

# %%
drop_columns = dict()
drop_columns['ssp_id'] = ['5vVGidhbcl','8hNBdRzeNs','k5ASnQBVC3']
drop_columns['campaign_id'] = ['0QD4feO4rI', '0YA3A341JC', '0atWS1rCZU', '0cIRQG21u2', '0dA7hY6Jmh', '2NlOV3Vhjb',
                             '5VQBexQXNd', '6YwKbksqUt', '7EFpAOriPb', '7bwbFU2aw6', '8X8MSt1MtI', '982JzgFzXr', '9DXd1SMTIX',
                             '9u2WPOwFIO', 'A5v8cl57kj', 'ABwpCp3BgR', 'AVzfqRypNN', 'BR6anCnZmX', 'CqaknOY8Ue', 'FJgon9wyQJ',
                             'Fek6tREzp4', 'GBfwACWj7p', 'GP1eYNQrvV', 'GWeY2G4BCb', 'GsCzUOJBfl', 'H2TwsEuKQ7', 'HwI3fRmwXj',
                             'IkHtBT4NIU', 'KBBU1tG4gZ', 'LQdKthViHn', 'LX8tVn1OAZ', 'Mpfcwe8njc', 'NDReJP21mw', 'Nd1Lgdj35v',
                             'Px7fWYRFxs', 'QMhWoQOBrW', 'RTjVa8eGWa', 'TbKQ7DwRbN', 'The3yiPLDh', 'U9Yi4dUTT8', 'UsWCM2N8Nn',
                             'VuzEmNib4Y', 'WShBIQKtW7', 'XKWXSikAa7', 'Yb4sshYDTk', 'b66JjLbDdr', 'dIoemJXuJ6', 'dS6rpIpBHY',
 'aJIWEya2xK', 'az1gtaaQUM', 'bEwKLmwRoo', 'caJ0ac15fJ', 'ckdSei0Hat', 'ctan8DAoon', 'cxf0Ti6WYE','d0GGxiVAaG', 'dW3t0NpbB6', 'dfjcYvKxRu', 'dtuutV876Z', 'duPmCtPU0s', 'e0vuTDZIg9', 'enaXScLbOa', 'fCZRCWNIjT', 'fLZ1XU475t', 'fhQSDYx57f', 'fiJqINpRUy',
 'gJOUisIOEi', 'gVA5rDGi3j', 'gc7JemIfjA', 'hYvmtyLalO', 'i0wvrNSQVd','iDQIqFXLOx', 'iRwfbhTa2u', 'igwNZ9dc2p', 'j6GKSlrzki', 'jhC2lEX4n7', 'kQzOoSPGym', 'lxFSSI9mrC', 'm1iThiKnJZ', 'mJEaLAl4sQ', 'mfGpk4kj0i', 'mpDxvHhkrb', 'msHdOZQaXS', 'myhZLTNmcs',
 'n2EkelvAAd', 'nAkrmXoE7u', 'nPHzB1ERWQ', 'nTzoQNNiyP', 'nz5kFLSj4p', 'o7AOnAJxmm', 'pPD5I5gJ6Y', 'pSyivyEZOg', 'q4fsTp0Gz1', 'qfRapz8Jr4', 'qwNQImkG8p', 'rQukFDdN8S', 'rgJKHtqJPy', 'rimI4qtel9', 'sU3tWO9sZw', 'sWxk9zXGjv', 'smW3wSn6kW', 'tDK30UuQ6p',
 'tIOqynmXvu', 'tPDLUG9EdK', 'tcDu3sbkeE', 'teI35fxw07', 'trndviTQNX', 'v96QdRs1HQ', 'vRdzpKwkBk', 'vvPyckoifE', 'w7DQi0ib3I', 'wF3AGS55xg', 'wpAk56d544', 'xCPhdvGj8k', 'xQUSdJnTfS', 'xhyY2FnOFZ', 'xtuOCAovGK', 'yCDzKsOy2o', 'yOUZcdkbd8',
 'z29gOe4wqw', 'z70x3AFupu', 'zSMrOhuA3P', 'zTUyG5IT5N', 'ze9k4RJrzB', 'zpEs9ZWpuT', 'zvwtmmd8Mi']
keep_columns['device_make'] = ['1DazYyqgrO', '1mOotgnQNd', 'HiGuczmB3W', 'SVCTRJ8bvW', 'U9Zas3Q5qy', 'javoIwtGqV', 'qNH7WLo7G9', 'rp6gWKT7zk']

# %%
def dummies(train_df, i):
  dum_train = pd.get_dummies(train_df[i])
  if i in ['ssp_id','campaign_id','device_language','advertisement_id','device_connection_type']:
    dum_train.drop(drop_columns[i], axis=1, inplace=True)
  else:
    dum_train = dum_train.loc[:,keep_columns[i]]
  return dum_train

# %%
def output(i, dum_train):
  name = 'others_'+i
  name2 = i+'_fs'
  dum_train = dum_train*2
  dum_train[name] = 1
  train_out = pd.DataFrame(dum_train.idxmax(axis=1), columns=[name2])
  return train_out

# %%
train_set = train_df['bid_id']
for i in (train_df.columns[2:]):
  dummy_train = dummies(train_df, i)
  train_out = output(i, dummy_train)
  del dummy_train
  train_set = pd.concat([train_set, train_out], axis=1, ignore_index=True)
  del train_out
  print(head(train_set))

# %% [markdown]
# ### Train (hour, day, click_per_hour)

# %%
train_df['hour'] = train_df['event_datetime'].str.slice(11,13)

data= train_df.loc[:,['bid_id','click', 'hour']]

hour0=data[data['hour']==0]
hour1=data[data['hour']==1]
hour2=data[data['hour']==2]
hour3=data[data['hour']==3]
hour4=data[data['hour']==4]
hour5=data[data['hour']==5]
hour6=data[data['hour']==6]
hour7=data[data['hour']==7]
hour8=data[data['hour']==8]
hour9=data[data['hour']==9]
hour10=data[data['hour']==10]
hour11=data[data['hour']==11]
hour12=data[data['hour']==12]
hour13=data[data['hour']==13]
hour14=data[data['hour']==14]
hour15=data[data['hour']==15]
hour16=data[data['hour']==16]
hour17=data[data['hour']==17]
hour18=data[data['hour']==18]
hour19=data[data['hour']==19]
hour20=data[data['hour']==20]
hour21=data[data['hour']==21]
hour22=data[data['hour']==22]
hour23=data[data['hour']==23]

del data

hour0['click_per_hour']=len(hour0[hour0['click']==1])/len(hour0)
hour1['click_per_hour']=len(hour1[hour1['click']==1])/len(hour1)
hour2['click_per_hour']=len(hour2[hour2['click']==1])/len(hour2)
hour3['click_per_hour']=len(hour3[hour3['click']==1])/len(hour3)
hour4['click_per_hour']=len(hour4[hour4['click']==1])/len(hour4)
hour5['click_per_hour']=len(hour5[hour5['click']==1])/len(hour5)
hour6['click_per_hour']=len(hour6[hour6['click']==1])/len(hour6)
hour7['click_per_hour']=len(hour7[hour7['click']==1])/len(hour7)
hour8['click_per_hour']=len(hour8[hour8['click']==1])/len(hour8)
hour9['click_per_hour']=len(hour9[hour9['click']==1])/len(hour9)
hour10['click_per_hour']=len(hour10[hour10['click']==1])/len(hour10)
hour11['click_per_hour']=len(hour11[hour11['click']==1])/len(hour11)
hour12['click_per_hour']=len(hour12[hour12['click']==1])/len(hour12)
hour13['click_per_hour']=len(hour13[hour13['click']==1])/len(hour13)
hour14['click_per_hour']=len(hour14[hour14['click']==1])/len(hour14)
hour15['click_per_hour']=len(hour15[hour15['click']==1])/len(hour15)
hour16['click_per_hour']=len(hour16[hour16['click']==1])/len(hour16)
hour17['click_per_hour']=len(hour17[hour17['click']==1])/len(hour17)
hour18['click_per_hour']=len(hour18[hour18['click']==1])/len(hour18)
hour19['click_per_hour']=len(hour19[hour19['click']==1])/len(hour19)
hour20['click_per_hour']=len(hour20[hour20['click']==1])/len(hour20)
hour21['click_per_hour']=len(hour21[hour21['click']==1])/len(hour21)
hour22['click_per_hour']=len(hour22[hour22['click']==1])/len(hour22)
hour23['click_per_hour']=len(hour23[hour23['click']==1])/len(hour23)



click_per_hour=pd.concat([hour0,hour1,hour2,hour3,hour4,hour5,hour6,hour7,hour8,hour9,hour10,hour11,hour12,hour13,hour14,
                         hour15,hour16,hour17,hour18,hour19,hour20,hour21,hour22,hour23],axis=0)
click_per_hour=click_per_hour.drop(['click','hour'],axis=1)

train_df = train_df.merge(click_per_hour, how='left', on="bid_id")

# %%
train_df['day']=train_df['event_datetime'].str.slice(8,10)

train_df['dayofweek']=train_df['day'].map({'01':'2',
                                           '02':'3',
                                           '03':'4',
                                           '04':'5',
                                           '05':'6',
                                           '06':'0',
                                           '07':'1',
                                           '08':'2',
                                           '09':'3',
                                           '10':'4',
                                           '11':'5',
                                           '12':'6'})
add_df=train_df['hour','dayofweek','click']
train_set=pd.concat([add_df,train_set],axis=1)

train_set.to_csv('train_preprocess_1.csv',index=False)
